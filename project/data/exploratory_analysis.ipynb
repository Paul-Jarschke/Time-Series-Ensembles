# %%
import pandas as pd

# %%
# Read data
df = pd.read_csv('eurusd_df.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143713 entries, 0 to 143712
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   datetime   143713 non-null  object
#  1   bid_open   101921 non-null  float64
#  2   bid_high   101921 non-null  float64
#  3   bid_low    101921 non-null  float64
#  4   bid_close  101921 non-null  float64
#  5   ask_open   101921 non-null  float64
#  6   ask_high   101921 non-null  float64
#  7   ask_low    101921 non-null  float64
#  8   ask_close  101921 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 9.9+ MB

# %%
display(df)
# Out:
#                    datetime  bid_open  bid_high  bid_low  bid_close  ask_open  \
# 0       2020-01-01 00:00:00       NaN       NaN      NaN        NaN       NaN
# 1       2020-01-01 00:15:00       NaN       NaN      NaN        NaN       NaN
# 2       2020-01-01 00:30:00       NaN       NaN      NaN        NaN       NaN
# 3       2020-01-01 00:45:00       NaN       NaN      NaN        NaN       NaN
# 4       2020-01-01 01:00:00       NaN       NaN      NaN        NaN       NaN
# ...                     ...       ...       ...      ...        ...       ...
# 143708  2024-02-05 23:00:00   1.07424   1.07426  1.07414    1.07419   1.07443
# 143709  2024-02-05 23:15:00   1.07419   1.07426  1.07419    1.07423   1.07439
# 143710  2024-02-05 23:30:00   1.07423   1.07423  1.07403    1.07420   1.07438
# 143711  2024-02-05 23:45:00   1.07420   1.07427  1.07401    1.07404   1.07437
# 143712  2024-02-06 00:00:00   1.07403   1.07432  1.07403    1.07415   1.07419
#
# ...

# %%
# Count the number of rows with at least one NaN value
num_rows_with_nan = df.isnull().any(axis=1).sum()

# Display the result
print("Number of rows with at least one NaN value:", num_rows_with_nan)
print(f"Share of rows with at least one NaN values: {round(num_rows_with_nan/len(df),4)}")
# Out:
# Number of rows with at least one NaN value: 41792
# Share of rows with at least one NaN values: 0.2908

# %%
data = df.dropna()

# %%
data
# Out:
#                    datetime  bid_open  bid_high  bid_low  bid_close  ask_open  \
# 96      2020-01-02 00:00:00   1.12184   1.12186  1.12156    1.12157   1.12198
# 97      2020-01-02 00:15:00   1.12154   1.12164  1.12151    1.12155   1.12168
# 98      2020-01-02 00:30:00   1.12157   1.12169  1.12152    1.12167   1.12169
# 99      2020-01-02 00:45:00   1.12169   1.12183  1.12169    1.12178   1.12181
# 100     2020-01-02 01:00:00   1.12177   1.12225  1.12176    1.12221   1.12190
# ...                     ...       ...       ...      ...        ...       ...
# 143708  2024-02-05 23:00:00   1.07424   1.07426  1.07414    1.07419   1.07443
# 143709  2024-02-05 23:15:00   1.07419   1.07426  1.07419    1.07423   1.07439
# 143710  2024-02-05 23:30:00   1.07423   1.07423  1.07403    1.07420   1.07438
# 143711  2024-02-05 23:45:00   1.07420   1.07427  1.07401    1.07404   1.07437
# 143712  2024-02-06 00:00:00   1.07403   1.07432  1.07403    1.07415   1.07419
#
# ...

# %%
# Validation for nan removal
if data.isnull().sum().sum() == 0:
    print("There are no NaN or null values in the DataFrame after cleaning.")
else:
    print("There are still NaN or null values in the DataFrame after cleaning.")
# Out:
# There are no NaN or null values in the DataFrame after cleaning.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plot 'bid_open' as a line plot
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['bid_open'], label='Bid Open', color='blue')
plt.title('Bid Open over Time')
plt.xlabel('Index')
plt.ylabel('Bid Open')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot all variables in one plot
plt.figure(figsize=(10, 6))
data.plot(ax=plt.gca())  # Passing the current axis to plot all columns
plt.title('Variables over Time')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid(True)
plt.legend(loc='upper left')  # You can adjust the location of the legend as needed
plt.show()
