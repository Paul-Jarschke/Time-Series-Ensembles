# %% [markdown]
# # Interface for Pipeline Execution
# ## (Simulated Data from SARIMAX Process)

# %% [markdown]
# ## 1) Import Models, Metrics, Paths, and Functions

# %%
from src.utils.helpers import csv_reader
from src.utils.paths import *
from src.paper import display_ranking_table
from src.pipeline.run_pipeline import run_pipeline

from src.models import MODELS
from src.metrics import METRICS
# Out:
# Loading helper functions...
# Loading paths...
# Loading data transformers...
# Loading models...
# Loading metrics...
#
# Successfully loaded metrics: MAPE, RMSE, sMAPE
#
# Successfully loaded forecasters:
#  - without covariates: skProphet, Naive, Naive (drift), AutoSARIMA, Exponential Smoothing, STL, XGBoost, dartsProphet
#  - covariates: AutoSARIMAX, XGBoostCov
#
# Successfully loaded ensemblers:
#  - weighted: Simple, Inverse RMSE, Inverse Variance, Inverse Error Covariance
#  - meta: SVR, Random Forest, MLP

# %% [markdown]
# ## 2) Load Simulated Data

# %%
select_datasets = ["RW", "TrendSeasRW", "WeakSARIMA", "StrongSARIMA", "SARIMAX"]
df_dict = {}
for file in os.listdir(SIMDATA_DIR):
    if file.replace(".csv", "") in select_datasets:
        df = csv_reader(SIMDATA_DIR, file)
        df_dict[df.attrs['file_name']] = df
    else:
        print(f"Skipping {file}...")

# %%
display(df_dict['RW'].head())
# Out:
#                    RW
# Date
# 2004-01-01  75.088420
# 2004-02-01  72.932225
# 2004-03-01  60.153464
# 2004-04-01  57.815302
# 2004-05-01  54.129793

# %% [markdown]
# ## 3) Run Pipeline

# %%
#df_dict = df_dict["StrongSARIMA"]
output_dictionaries = run_pipeline(
    df=df_dict, models=MODELS, metrics=METRICS,
    # end="2010-12-31",
    # select_ensemblers=["Inverse Error Covariance"],
    # select_forecasters=["Naive", "Exponential Smoothing"],
    fh=1, verbose=True, export_path=PAPER_PIPE_OUTPUT_DIR
)
# Out:
# =================================================================================
# [2024-03-10 17:36] Starting  Pipeline for RW...
#
# =========================================
# == Pipeline Step 1: Data Preprocessing ==
# =========================================
#
# Searching time information...
# Dates found in 'index' column!
# Inferred frequency: month start
# Data goes from 2004-01 to 2023-12, resulting in 240 observations.
#
# Selecting target and covariates...
# Target: RW
# Covariates: None
#
# Data Insights:
#                 RW
# Date
# 2004-01  75.088420
# 2004-02  72.932225
# 2004-03  60.153464
# 2004-04  57.815302
# 2004-05  54.129793
#
# [Time elapsed: 00s]
#
#
# =====================================================
# == Pipeline Step 2: Individual Models' Predictions ==
# =====================================================
#
# Splitting data for training of forecasters (train/test ratio: 30/70)...
# Initial training set has 72 observations and goes from 2004-01 to 2009-12.
#
# In an historical expanding window approach, there are 168 periods to be forecasted by the individual models: 2010-01 to 2023-12
# Out-of-sample predictions are generated for next period: 2024-01
#
# Now generating 168 one-step ahead historical expanding window predictions from model: skProphet (sktime)
# cmd: where.exe tbb.dll
# cwd: None
# Adding TBB (C:\Users\Work\OneDrive\GAU\3. Semester\Statistisches Praktikum\Git\NEW_Ensemble_Techniques_TS_FC\venv\Lib\site-packages\prophet\stan_model\cmdstan-2.33.1\stan\lib\stan_math\lib\tbb) to PATH
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\0qhnonek.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\oxxvymz7.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=84441', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\0qhnonek.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\oxxvymz7.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model6saq3n1o\\prophet_model-20240310173626.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:26 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:26 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\6jmutb93.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\3vh2tru9.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=22935', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\6jmutb93.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\3vh2tru9.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelqd6c433g\\prophet_model-20240310173627.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:27 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:27 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\cs8iswoe.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\eji3hlch.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=23584', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\cs8iswoe.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\eji3hlch.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelh5x1tsfb\\prophet_model-20240310173628.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:28 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:29 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\xqqi_jnc.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\3ce3i_xg.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=21032', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\xqqi_jnc.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\3ce3i_xg.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model9bi2cjxs\\prophet_model-20240310173629.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:29 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:30 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\pu84f3n1.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\d8udommn.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=35535', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\pu84f3n1.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\d8udommn.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelxofdfss8\\prophet_model-20240310173630.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:30 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:31 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\orbu_qk6.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\1vf9p7rl.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=23976', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\orbu_qk6.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\1vf9p7rl.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelhpaw_vrp\\prophet_model-20240310173631.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:31 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:32 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\7obeb0pm.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\ywnbgpoz.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=13898', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\7obeb0pm.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\ywnbgpoz.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model_22yt1t2\\prophet_model-20240310173632.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:32 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:33 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\hlrzllu8.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\j_efjs79.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=77650', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\hlrzllu8.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\j_efjs79.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model7_0lkjax\\prophet_model-20240310173633.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:33 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:34 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\j_csniri.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\15eewyj1.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=86903', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\j_csniri.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\15eewyj1.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_models85ejge8\\prophet_model-20240310173634.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:34 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:35 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\z6j9jl4b.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\9y0fjpo7.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=92015', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\z6j9jl4b.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\9y0fjpo7.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelr5dltbjm\\prophet_model-20240310173635.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:35 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:36 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\ikdzgkpe.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\ephpqeky.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=135', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\ikdzgkpe.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\ephpqeky.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model2ty2zlzu\\prophet_model-20240310173637.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:37 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:37 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\i1rvrlqq.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\y5pu4vz2.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=49073', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\i1rvrlqq.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\y5pu4vz2.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modeldboo_uyo\\prophet_model-20240310173637.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:37 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:38 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\dt9_alka.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\bcovroxz.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=56745', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\dt9_alka.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\bcovroxz.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modellmij5a1b\\prophet_model-20240310173639.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:39 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:40 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\rb_bx3yu.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\zdc7h5cj.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=53878', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\rb_bx3yu.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\zdc7h5cj.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model31co9bla\\prophet_model-20240310173640.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:40 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:41 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\77paj3zz.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\82h50yfb.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=14304', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\77paj3zz.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\82h50yfb.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modely2q1rv5r\\prophet_model-20240310173641.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:41 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:41 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\40nyddfn.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\awaho7f2.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=12532', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\40nyddfn.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\awaho7f2.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelqpvzross\\prophet_model-20240310173642.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:42 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:43 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\gos9nuro.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\t84m7b8n.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=59242', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\gos9nuro.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\t84m7b8n.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelt_s2e2y2\\prophet_model-20240310173643.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:43 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:44 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\elvg1wt3.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\8awgz7ar.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=27386', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\elvg1wt3.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\8awgz7ar.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelx8m962li\\prophet_model-20240310173645.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:45 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:45 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\c3q1ai2r.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\5upoqi7h.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=37634', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\c3q1ai2r.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\5upoqi7h.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model4jabgsxp\\prophet_model-20240310173646.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:46 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:46 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\_ue1xiqz.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\1uit0n_5.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=10444', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\_ue1xiqz.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\1uit0n_5.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelvybofc5p\\prophet_model-20240310173647.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:47 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:48 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\0m0d8v9s.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\jgwn852x.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=50099', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\0m0d8v9s.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\jgwn852x.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model94h34exa\\prophet_model-20240310173648.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:48 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:49 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\yf26reuk.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\e_1x338h.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=17001', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\yf26reuk.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\e_1x338h.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelfvam9qwz\\prophet_model-20240310173649.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:49 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:50 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\1wl0zn7q.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\h0yax7_1.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=51315', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\1wl0zn7q.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\h0yax7_1.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modele_p_a03l\\prophet_model-20240310173651.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:51 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:52 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\zrjr_3bw.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\uskxi7tw.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=9402', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\zrjr_3bw.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\uskxi7tw.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modeladhyqz08\\prophet_model-20240310173652.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:52 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:53 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\58g0xpa3.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\ac5o1w0k.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=40160', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\58g0xpa3.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\ac5o1w0k.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelnklehg7k\\prophet_model-20240310173654.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:54 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:55 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\pnj70yok.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\m2pzw7jo.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=66382', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\pnj70yok.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\m2pzw7jo.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model2yeevaa2\\prophet_model-20240310173655.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:55 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:56 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\umseqk_0.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\2om9fmmy.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=74978', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\umseqk_0.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\2om9fmmy.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model1u3nhntx\\prophet_model-20240310173656.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:56 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:57 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\lyol4kqe.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\jgonjx1i.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=4058', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\lyol4kqe.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\jgonjx1i.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelqtnqwny0\\prophet_model-20240310173658.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:58 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:36:58 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\3yh16x0m.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\h0u4mxzp.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=72779', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\3yh16x0m.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\h0u4mxzp.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model7cdjuhdn\\prophet_model-20240310173659.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:36:59 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:37:00 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\_3ernxb8.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\gmf8ff_z.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=21403', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\_3ernxb8.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\gmf8ff_z.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modeljb_c3tdy\\prophet_model-20240310173700.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:37:00 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:37:00 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\j23it_jo.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\ihfak0e7.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=27426', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\j23it_jo.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\ihfak0e7.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelobq6kd2i\\prophet_model-20240310173701.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:37:01 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:37:01 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\ji9wjc1l.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\0jlejps_.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=24215', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\ji9wjc1l.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\0jlejps_.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelzd5jeebw\\prophet_model-20240310173701.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:37:01 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:37:01 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\08l571ei.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\gi1p6som.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=34935', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\08l571ei.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\gi1p6som.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelvwt3vk2a\\prophet_model-20240310173702.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:37:02 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:37:02 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\g20e2aek.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\yephey_v.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=7073', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\g20e2aek.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\yephey_v.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelcf72j_th\\prophet_model-20240310173702.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:37:02 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:37:02 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\znhrvjme.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\gqg2vrqk.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=12484', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\znhrvjme.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\gqg2vrqk.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model56ge012a\\prophet_model-20240310173703.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:37:03 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:37:03 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\pn5wqwqi.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\83dlop6l.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=89801', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\pn5wqwqi.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\83dlop6l.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model6hrf1j8m\\prophet_model-20240310173703.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:37:03 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:37:03 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\edpv77dh.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\crjrgw0p.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=66717', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\edpv77dh.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\crjrgw0p.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model_00_byri\\prophet_model-20240310173704.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:37:04 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:37:04 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\6g2tmwf2.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\31b80kiy.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=34237', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\6g2tmwf2.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\31b80kiy.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelkpir8fgb\\prophet_model-20240310173704.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:37:04 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:37:04 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\3vuru0xd.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\kk536smn.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=92298', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\3vuru0xd.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\kk536smn.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model6utvh51s\\prophet_model-20240310173705.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:37:05 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:37:05 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\27wfvgkx.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\4flc59t_.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=22453', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\27wfvgkx.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\4flc59t_.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model6j42i8xi\\prophet_model-20240310173705.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:37:05 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 17:37:05 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\aksey0ql.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\zho4cckv.json
# idx 0
# running CmdStan, num_threads: None
# ...
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\5_ozi_qm.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\xn8glmih.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=87993', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\5_ozi_qm.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\xn8glmih.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model3nlx2f2i\\prophet_model-20240310182249.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 18:22:49 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 18:22:49 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\6jb4j0ud.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\jz8uyezz.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=1602', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\6jb4j0ud.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\jz8uyezz.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_model54psz_f1\\prophet_model-20240310182250.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 18:22:50 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 18:22:50 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\g95hb906.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\1fjbdiqf.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=90803', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\g95hb906.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\1fjbdiqf.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelwntpadhs\\prophet_model-20240310182250.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 18:22:50 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 18:22:50 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# Now performing corresponding out-of-sample predictions...
# cmd: where.exe tbb.dll
# cwd: None
# TBB already found in load path
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\rl8i3wmg.json
# input tempfile: C:\Users\Work\AppData\Local\Temp\tmp762htgb5\88qmj51v.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['C:\\Users\\Work\\OneDrive\\GAU\\3. Semester\\Statistisches Praktikum\\Git\\NEW_Ensemble_Techniques_TS_FC\\venv\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=76043', 'data', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\rl8i3wmg.json', 'init=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\88qmj51v.json', 'output', 'file=C:\\Users\\Work\\AppData\\Local\\Temp\\tmp762htgb5\\prophet_modelhfb7emt1\\prophet_model-20240310182251.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 18:22:51 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] start processing
# 18:22:51 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] done processing
# ...finished!
#
# Skipping covariate forecasters since no covariates are given.
#
# Finished predictions of individual forecasters!
#
# Insights into forecasters' historical predictions:
#          skProphet      Naive  Naive (drift)  AutoSARIMA  \
# Date
# 2010-01  51.898329  54.125598      53.932514   53.419395
# 2010-02  54.598773  54.391598      54.204890   55.400318
# 2010-03  53.706849  55.414677      55.244541   54.473555
# 2010-04  53.118736  57.505825      57.366247   56.715515
# 2010-05  51.502121  54.400890      54.221774   54.307201
#
#          Exponential Smoothing        STL    XGBoost  dartsProphet
# Date
# 2010-01              53.209749  54.909797  53.260006     51.846938
# 2010-02              56.448705  59.503070  49.700474     55.194335
# 2010-03              53.331175  54.191112  53.145664     53.363296
# 2010-04              54.953830  52.546657  56.468643     53.114445
# 2010-05              53.039425  50.757380  49.862255     51.576067
#
# Insights into forecasters' future predictions:
#          skProphet    Naive  Naive (drift)  AutoSARIMA  Exponential Smoothing  \
# Date
# 2024-01  85.501826  80.9192      80.973948      81.193              81.339129
#
#                STL    XGBoost  dartsProphet
# Date
# 2024-01  83.754654  82.660751     85.448845
#
# [Time elapsed: 46m 25s]
#
#
# ===================================================
# == Pipeline Step 3: Ensemble Models' Predictions ==
# ===================================================
#
# Splitting individual forecast data (n = 168) for training of ensemblers (train/test ratio: 25/75)...
# Initial training set has 42 observations and goes from 2010-01 to 2013-06
#
# In an historical expanding window approach, there are 126 periods to be forecasted by the ensemble models: 2013-07 to 2023-12
# Out-of-sample predictions are generated for next period: 2023-12-31 00:00:00
#
# Now generating 126 one-step ahead historical expanding window predictions from ensemble model: 'Weighted - Simple'
# ...Forecast 1 / 126
# ...Forecast 32 / 126
# ...Forecast 63 / 126
# ...Forecast 95 / 126
# ...finished!
# Performing out-of-sample predictions...
# ...finished!
#
# Now generating 126 one-step ahead historical expanding window predictions from ensemble model: 'Weighted - Inverse RMSE'
# ...Forecast 1 / 126
# ...Forecast 32 / 126
# ...Forecast 63 / 126
# ...Forecast 95 / 126
# ...finished!
# Performing out-of-sample predictions...
# ...finished!
#
# Now generating 126 one-step ahead historical expanding window predictions from ensemble model: 'Weighted - Inverse Variance'
# ...Forecast 1 / 126
# ...Forecast 32 / 126
# ...Forecast 63 / 126
# ...Forecast 95 / 126
# ...finished!
# Performing out-of-sample predictions...
# ...finished!
#
# Now generating 126 one-step ahead historical expanding window predictions from ensemble model: 'Weighted - Inverse Error Covariance'
# ...Forecast 1 / 126
# ...Forecast 32 / 126
# ...Forecast 63 / 126
# ...Forecast 95 / 126
# ...finished!
# Performing out-of-sample predictions...
# ...finished!
#
# Now generating 126 one-step ahead historical expanding window predictions from ensemble model: 'Meta - SVR (sklearn)'
# ...Forecast 1 / 126
# ...Forecast 32 / 126
# ...Forecast 63 / 126
# ...Forecast 95 / 126
# ...finished!
# Performing out-of-sample predictions...
# ...finished!
#
# Now generating 126 one-step ahead historical expanding window predictions from ensemble model: 'Meta - Random Forest (sklearn)'
# ...Forecast 1 / 126
# ...Forecast 32 / 126
# ...Forecast 63 / 126
# ...Forecast 95 / 126
# ...finished!
# Performing out-of-sample predictions...
# ...finished!
#
# Now generating 126 one-step ahead historical expanding window predictions from ensemble model: 'Meta - MLP (sklearn)'
# ...Forecast 1 / 126
# ...Forecast 32 / 126
# ...Forecast 63 / 126
# ...Forecast 95 / 126
# ...finished!
# Performing out-of-sample predictions...
# ...finished!
#
# Finished predictions of ensemble forecasters!
#
# Insights into ensemblers' historical predictions:
#          Weighted Ensemble: Simple  Weighted Ensemble: Inverse RMSE  \
# 2013-07                  68.468142                        68.262319
# 2013-08                  65.267050                        65.110699
# 2013-09                  65.249654                        65.080971
# 2013-10                  61.957306                        61.712870
# 2013-11                  61.549518                        61.161046
#
#          Weighted Ensemble: Inverse Variance  \
# 2013-07                            68.112396
# 2013-08                            64.918130
# 2013-09                            65.321632
# 2013-10                            61.384823
# 2013-11                            60.767883
#
#          Weighted Ensemble: Inverse Error Covariance  Meta Ensemble: SVR  \
# 2013-07                                    68.967630           68.555228
# 2013-08                                    68.071077           66.227591
# 2013-09                                    64.642259           62.800245
# 2013-10                                    63.304434           64.147410
# 2013-11                                    62.190877           61.513070
#
#          Meta Ensemble: Random Forest  Meta Ensemble: MLP
# 2013-07                     68.259506           77.791992
# 2013-08                     64.167541           73.395309
# 2013-09                     61.456877           72.714654
# 2013-10                     63.017826           69.495735
# 2013-11                     60.620131           71.228533
#
# Insights into ensemblers' future predictions:
#          Weighted Ensemble: Simple  Weighted Ensemble: Inverse RMSE  \
# Date
# 2024-01                  82.723919                        82.334431
#
#          Weighted Ensemble: Inverse Variance  \
# Date
# 2024-01                            82.692202
#
#          Weighted Ensemble: Inverse Error Covariance  Meta Ensemble: SVR  \
# Date
# 2024-01                                    81.031552           81.502467
#
#          Meta Ensemble: Random Forest  Meta Ensemble: MLP
# Date
# 2024-01                     82.097311           96.618987
#
# Merging...
# ...finished!
#
#
# Exporting historical predictions and future predictions as csv to C:\Users\Work\OneDrive\GAU\3. Semester\Statistisches Praktikum\Git\NEW_Ensemble_Techniques_TS_FC\paper\pipeline\outputs\20240310_1736\WeakSARIMA...
# ...finished!
#
# [Time elapsed: 47m 16s]
#
#
# ==============================================================
# == Pipeline Step 4: Ranking Models' Predictive Performance ==
# ==============================================================
#
# Calculating MAPE, RMSE, sMAPE per model...
# Ranking models ...
# ...finished!
#
# Results:
#                                                  MAPE       RMSE     sMAPE  \
# Model
# Weighted Ensemble: Inverse Error Covariance  0.030070   2.736729  2.004200
# Weighted Ensemble: Inverse RMSE              0.030114   2.711477  2.008184
# Weighted Ensemble: Inverse Variance          0.030716   2.769561  2.049721
# Exponential Smoothing                        0.030866   2.743687  2.056202
# AutoSARIMA                                   0.031148   2.710313  2.073020
# Weighted Ensemble: Simple                    0.031419   2.820026  2.095635
# Meta Ensemble: SVR                           0.031738   2.910520  2.119675
# Meta Ensemble: Random Forest                 0.032436   2.960930  2.166452
# Naive                                        0.032951   2.791199  2.194743
# Naive (drift)                                0.033013   2.798546  2.198737
# XGBoost                                      0.034701   3.180757  2.328224
# STL                                          0.044823   3.999710  2.979882
# dartsProphet                                 0.057928   4.982131  3.864066
# skProphet                                    0.058383   5.016619  3.894462
# Meta Ensemble: MLP                           0.137689  10.568929  8.705695
#
#                                              MAPE Ranking  RMSE Ranking  \
# Model
# Weighted Ensemble: Inverse Error Covariance             1             3
# Weighted Ensemble: Inverse RMSE                         2             2
# Weighted Ensemble: Inverse Variance                     3             5
# Exponential Smoothing                                   4             4
# AutoSARIMA                                              5             1
# Weighted Ensemble: Simple                               6             8
# Meta Ensemble: SVR                                      7             9
# Meta Ensemble: Random Forest                            8            10
# Naive                                                   9             6
# Naive (drift)                                          10             7
# XGBoost                                                11            11
# STL                                                    12            12
# dartsProphet                                           13            13
# skProphet                                              14            14
# Meta Ensemble: MLP                                     15            15
#
#                                              sMAPE Ranking
# Model
# Weighted Ensemble: Inverse Error Covariance              1
# Weighted Ensemble: Inverse RMSE                          2
# Weighted Ensemble: Inverse Variance                      3
# Exponential Smoothing                                    4
# AutoSARIMA                                               5
# Weighted Ensemble: Simple                                6
# Meta Ensemble: SVR                                       7
# Meta Ensemble: Random Forest                             8
# Naive                                                    9
# Naive (drift)                                           10
# XGBoost                                                 11
# STL                                                     12
# dartsProphet                                            13
# skProphet                                               14
# Meta Ensemble: MLP                                      15
#
# The 'Weighted Ensemble: Inverse Error Covariance' is identified as the best model based on the MAPE value of its the historical predictions.
# Thus, it is recommended to work with the future predictions coming from this model:
# Date
# 2024-01    81.031552
# Freq: M, Name: Weighted Ensemble: Inverse Error Covariance, dtype: float64
#
# Exporting metrics_ranking as csv to C:\Users\Work\OneDrive\GAU\3. Semester\Statistisches Praktikum\Git\NEW_Ensemble_Techniques_TS_FC\paper\pipeline\outputs\20240310_1736\WeakSARIMA...
# ...finished!
# Saving logfile to C:\Users\Work\OneDrive\GAU\3. Semester\Statistisches Praktikum\Git\NEW_Ensemble_Techniques_TS_FC\paper\pipeline\outputs\log_file.log
#
# [2024-03-10 18:23] Finished Pipeline for WeakSARIMA!
# [Total time elapsed: 47m 17s]
# =================================================================================

# %% [markdown]
# ## 3) Show Ranking Tables

# %%
# Sort
# sorted(output_dictionaries.items(), key=lambda pair: select_datasets.index(pair[0]))
# Show
for df, output_dict in output_dictionaries.items():
    print(f"Metrics ranking for {df}:")
    display_ranking_table(output_dict['metrics ranking'])
    print("\n")
# Out:
# Metrics ranking for RW:
# <style type="text/css">
# </style>
# <table id="T_024cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_024cd_level0_col0" class="col_heading level0 col0" >MAPE</th>
#       <th id="T_024cd_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_024cd_level0_col2" class="col_heading level0 col2" >sMAPE</th>
#       <th id="T_024cd_level0_col3" class="col_heading level0 col3" >MAPE Ranking</th>
#       <th id="T_024cd_level0_col4" class="col_heading level0 col4" >RMSE Ranking</th>
#       <th id="T_024cd_level0_col5" class="col_heading level0 col5" >sMAPE Ranking</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_024cd_level0_row0" class="row_heading level0 row0" >AutoSARIMA</th>
#       <td id="T_024cd_row0_col0" class="data row0 col0" >0.057</td>
#       <td id="T_024cd_row0_col1" class="data row0 col1" >4.966</td>
#       <td id="T_024cd_row0_col2" class="data row0 col2" >3.776</td>
#       <td id="T_024cd_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_024cd_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_024cd_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row1" class="row_heading level0 row1" >Weighted Ensemble: Inverse RMSE</th>
#       <td id="T_024cd_row1_col0" class="data row1 col0" >0.057</td>
#       <td id="T_024cd_row1_col1" class="data row1 col1" >5.028</td>
#       <td id="T_024cd_row1_col2" class="data row1 col2" >3.788</td>
#       <td id="T_024cd_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_024cd_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_024cd_row1_col5" class="data row1 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row2" class="row_heading level0 row2" >Weighted Ensemble: Inverse Variance</th>
#       <td id="T_024cd_row2_col0" class="data row2 col0" >0.059</td>
#       <td id="T_024cd_row2_col1" class="data row2 col1" >5.140</td>
#       <td id="T_024cd_row2_col2" class="data row2 col2" >3.904</td>
#       <td id="T_024cd_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_024cd_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_024cd_row2_col5" class="data row2 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row3" class="row_heading level0 row3" >Naive</th>
#       <td id="T_024cd_row3_col0" class="data row3 col0" >0.059</td>
#       <td id="T_024cd_row3_col1" class="data row3 col1" >5.150</td>
#       <td id="T_024cd_row3_col2" class="data row3 col2" >3.925</td>
#       <td id="T_024cd_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_024cd_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_024cd_row3_col5" class="data row3 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row4" class="row_heading level0 row4" >Naive (drift)</th>
#       <td id="T_024cd_row4_col0" class="data row4 col0" >0.059</td>
#       <td id="T_024cd_row4_col1" class="data row4 col1" >5.165</td>
#       <td id="T_024cd_row4_col2" class="data row4 col2" >3.938</td>
#       <td id="T_024cd_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_024cd_row4_col4" class="data row4 col4" >5</td>
#       <td id="T_024cd_row4_col5" class="data row4 col5" >5</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row5" class="row_heading level0 row5" >Weighted Ensemble: Inverse Error Covariance</th>
#       <td id="T_024cd_row5_col0" class="data row5 col0" >0.060</td>
#       <td id="T_024cd_row5_col1" class="data row5 col1" >5.212</td>
#       <td id="T_024cd_row5_col2" class="data row5 col2" >3.950</td>
#       <td id="T_024cd_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_024cd_row5_col4" class="data row5 col4" >6</td>
#       <td id="T_024cd_row5_col5" class="data row5 col5" >6</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row6" class="row_heading level0 row6" >Weighted Ensemble: Simple</th>
#       <td id="T_024cd_row6_col0" class="data row6 col0" >0.060</td>
#       <td id="T_024cd_row6_col1" class="data row6 col1" >5.247</td>
#       <td id="T_024cd_row6_col2" class="data row6 col2" >3.987</td>
#       <td id="T_024cd_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_024cd_row6_col4" class="data row6 col4" >7</td>
#       <td id="T_024cd_row6_col5" class="data row6 col5" >7</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row7" class="row_heading level0 row7" >Exponential Smoothing</th>
#       <td id="T_024cd_row7_col0" class="data row7 col0" >0.060</td>
#       <td id="T_024cd_row7_col1" class="data row7 col1" >5.274</td>
#       <td id="T_024cd_row7_col2" class="data row7 col2" >4.001</td>
#       <td id="T_024cd_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_024cd_row7_col4" class="data row7 col4" >8</td>
#       <td id="T_024cd_row7_col5" class="data row7 col5" >8</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row8" class="row_heading level0 row8" >Meta Ensemble: Random Forest</th>
#       <td id="T_024cd_row8_col0" class="data row8 col0" >0.062</td>
#       <td id="T_024cd_row8_col1" class="data row8 col1" >5.551</td>
#       <td id="T_024cd_row8_col2" class="data row8 col2" >4.115</td>
#       <td id="T_024cd_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_024cd_row8_col4" class="data row8 col4" >11</td>
#       <td id="T_024cd_row8_col5" class="data row8 col5" >9</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row9" class="row_heading level0 row9" >Meta Ensemble: SVR</th>
#       <td id="T_024cd_row9_col0" class="data row9 col0" >0.063</td>
#       <td id="T_024cd_row9_col1" class="data row9 col1" >5.357</td>
#       <td id="T_024cd_row9_col2" class="data row9 col2" >4.158</td>
#       <td id="T_024cd_row9_col3" class="data row9 col3" >10</td>
#       <td id="T_024cd_row9_col4" class="data row9 col4" >9</td>
#       <td id="T_024cd_row9_col5" class="data row9 col5" >10</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row10" class="row_heading level0 row10" >XGBoost</th>
#       <td id="T_024cd_row10_col0" class="data row10 col0" >0.063</td>
#       <td id="T_024cd_row10_col1" class="data row10 col1" >5.522</td>
#       <td id="T_024cd_row10_col2" class="data row10 col2" >4.181</td>
#       <td id="T_024cd_row10_col3" class="data row10 col3" >11</td>
#       <td id="T_024cd_row10_col4" class="data row10 col4" >10</td>
#       <td id="T_024cd_row10_col5" class="data row10 col5" >11</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row11" class="row_heading level0 row11" >STL</th>
#       <td id="T_024cd_row11_col0" class="data row11 col0" >0.093</td>
#       <td id="T_024cd_row11_col1" class="data row11 col1" >7.961</td>
#       <td id="T_024cd_row11_col2" class="data row11 col2" >6.151</td>
#       <td id="T_024cd_row11_col3" class="data row11 col3" >12</td>
#       <td id="T_024cd_row11_col4" class="data row11 col4" >12</td>
#       <td id="T_024cd_row11_col5" class="data row11 col5" >12</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row12" class="row_heading level0 row12" >skProphet</th>
#       <td id="T_024cd_row12_col0" class="data row12 col0" >0.111</td>
#       <td id="T_024cd_row12_col1" class="data row12 col1" >9.146</td>
#       <td id="T_024cd_row12_col2" class="data row12 col2" >7.253</td>
#       <td id="T_024cd_row12_col3" class="data row12 col3" >13</td>
#       <td id="T_024cd_row12_col4" class="data row12 col4" >13</td>
#       <td id="T_024cd_row12_col5" class="data row12 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_024cd_level0_row13" class="row_heading level0 row13" >dartsProphet</th>
#       <td id="T_024cd_row13_col0" class="data row13 col0" >0.111</td>
#       <td id="T_024cd_row13_col1" class="data row13 col1" >9.182</td>
#       <td id="T_024cd_row13_col2" class="data row13 col2" >7.269</td>
#       <td id="T_024cd_row13_col3" class="data row13 col3" >14</td>
# Metrics ranking for SARIMAX:
# <style type="text/css">
# </style>
# <table id="T_058de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_058de_level0_col0" class="col_heading level0 col0" >MAPE</th>
#       <th id="T_058de_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_058de_level0_col2" class="col_heading level0 col2" >sMAPE</th>
#       <th id="T_058de_level0_col3" class="col_heading level0 col3" >MAPE Ranking</th>
#       <th id="T_058de_level0_col4" class="col_heading level0 col4" >RMSE Ranking</th>
#       <th id="T_058de_level0_col5" class="col_heading level0 col5" >sMAPE Ranking</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_058de_level0_row0" class="row_heading level0 row0" >AutoSARIMAX with covariates</th>
#       <td id="T_058de_row0_col0" class="data row0 col0" >0.028</td>
#       <td id="T_058de_row0_col1" class="data row0 col1" >2.610</td>
#       <td id="T_058de_row0_col2" class="data row0 col2" >1.852</td>
#       <td id="T_058de_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_058de_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_058de_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row1" class="row_heading level0 row1" >AutoSARIMA</th>
#       <td id="T_058de_row1_col0" class="data row1 col0" >0.028</td>
#       <td id="T_058de_row1_col1" class="data row1 col1" >2.678</td>
#       <td id="T_058de_row1_col2" class="data row1 col2" >1.868</td>
#       <td id="T_058de_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_058de_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_058de_row1_col5" class="data row1 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row2" class="row_heading level0 row2" >Naive (drift)</th>
#       <td id="T_058de_row2_col0" class="data row2 col0" >0.028</td>
#       <td id="T_058de_row2_col1" class="data row2 col1" >2.745</td>
#       <td id="T_058de_row2_col2" class="data row2 col2" >1.893</td>
#       <td id="T_058de_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_058de_row2_col4" class="data row2 col4" >7</td>
#       <td id="T_058de_row2_col5" class="data row2 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row3" class="row_heading level0 row3" >Naive</th>
#       <td id="T_058de_row3_col0" class="data row3 col0" >0.028</td>
#       <td id="T_058de_row3_col1" class="data row3 col1" >2.736</td>
#       <td id="T_058de_row3_col2" class="data row3 col2" >1.894</td>
#       <td id="T_058de_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_058de_row3_col4" class="data row3 col4" >6</td>
#       <td id="T_058de_row3_col5" class="data row3 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row4" class="row_heading level0 row4" >Weighted Ensemble: Inverse RMSE</th>
#       <td id="T_058de_row4_col0" class="data row4 col0" >0.029</td>
#       <td id="T_058de_row4_col1" class="data row4 col1" >2.686</td>
#       <td id="T_058de_row4_col2" class="data row4 col2" >1.914</td>
#       <td id="T_058de_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_058de_row4_col4" class="data row4 col4" >3</td>
#       <td id="T_058de_row4_col5" class="data row4 col5" >5</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row5" class="row_heading level0 row5" >Exponential Smoothing</th>
#       <td id="T_058de_row5_col0" class="data row5 col0" >0.029</td>
#       <td id="T_058de_row5_col1" class="data row5 col1" >2.719</td>
#       <td id="T_058de_row5_col2" class="data row5 col2" >1.920</td>
#       <td id="T_058de_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_058de_row5_col4" class="data row5 col4" >5</td>
#       <td id="T_058de_row5_col5" class="data row5 col5" >6</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row6" class="row_heading level0 row6" >Weighted Ensemble: Inverse Variance</th>
#       <td id="T_058de_row6_col0" class="data row6 col0" >0.029</td>
#       <td id="T_058de_row6_col1" class="data row6 col1" >2.716</td>
#       <td id="T_058de_row6_col2" class="data row6 col2" >1.942</td>
#       <td id="T_058de_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_058de_row6_col4" class="data row6 col4" >4</td>
#       <td id="T_058de_row6_col5" class="data row6 col5" >7</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row7" class="row_heading level0 row7" >Meta Ensemble: Random Forest</th>
#       <td id="T_058de_row7_col0" class="data row7 col0" >0.030</td>
#       <td id="T_058de_row7_col1" class="data row7 col1" >2.871</td>
#       <td id="T_058de_row7_col2" class="data row7 col2" >1.986</td>
#       <td id="T_058de_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_058de_row7_col4" class="data row7 col4" >10</td>
#       <td id="T_058de_row7_col5" class="data row7 col5" >8</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row8" class="row_heading level0 row8" >Weighted Ensemble: Simple</th>
#       <td id="T_058de_row8_col0" class="data row8 col0" >0.030</td>
#       <td id="T_058de_row8_col1" class="data row8 col1" >2.757</td>
#       <td id="T_058de_row8_col2" class="data row8 col2" >1.997</td>
#       <td id="T_058de_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_058de_row8_col4" class="data row8 col4" >8</td>
#       <td id="T_058de_row8_col5" class="data row8 col5" >9</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row9" class="row_heading level0 row9" >Weighted Ensemble: Inverse Error Covariance</th>
#       <td id="T_058de_row9_col0" class="data row9 col0" >0.030</td>
#       <td id="T_058de_row9_col1" class="data row9 col1" >2.850</td>
#       <td id="T_058de_row9_col2" class="data row9 col2" >2.006</td>
#       <td id="T_058de_row9_col3" class="data row9 col3" >10</td>
#       <td id="T_058de_row9_col4" class="data row9 col4" >9</td>
#       <td id="T_058de_row9_col5" class="data row9 col5" >10</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row10" class="row_heading level0 row10" >Meta Ensemble: SVR</th>
#       <td id="T_058de_row10_col0" class="data row10 col0" >0.032</td>
#       <td id="T_058de_row10_col1" class="data row10 col1" >2.922</td>
#       <td id="T_058de_row10_col2" class="data row10 col2" >2.102</td>
#       <td id="T_058de_row10_col3" class="data row10 col3" >11</td>
#       <td id="T_058de_row10_col4" class="data row10 col4" >11</td>
#       <td id="T_058de_row10_col5" class="data row10 col5" >11</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row11" class="row_heading level0 row11" >XGBoostCov with covariates</th>
#       <td id="T_058de_row11_col0" class="data row11 col0" >0.036</td>
#       <td id="T_058de_row11_col1" class="data row11 col1" >3.453</td>
#       <td id="T_058de_row11_col2" class="data row11 col2" >2.388</td>
#       <td id="T_058de_row11_col3" class="data row11 col3" >12</td>
#       <td id="T_058de_row11_col4" class="data row11 col4" >12</td>
#       <td id="T_058de_row11_col5" class="data row11 col5" >12</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row12" class="row_heading level0 row12" >XGBoost</th>
#       <td id="T_058de_row12_col0" class="data row12 col0" >0.037</td>
#       <td id="T_058de_row12_col1" class="data row12 col1" >3.555</td>
#       <td id="T_058de_row12_col2" class="data row12 col2" >2.471</td>
#       <td id="T_058de_row12_col3" class="data row12 col3" >13</td>
#       <td id="T_058de_row12_col4" class="data row12 col4" >13</td>
#       <td id="T_058de_row12_col5" class="data row12 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_058de_level0_row13" class="row_heading level0 row13" >STL</th>
#       <td id="T_058de_row13_col0" class="data row13 col0" >0.044</td>
#       <td id="T_058de_row13_col1" class="data row13 col1" >4.202</td>
#       <td id="T_058de_row13_col2" class="data row13 col2" >2.928</td>
#       <td id="T_058de_row13_col3" class="
# Metrics ranking for StrongSARIMA:
# <style type="text/css">
# </style>
# <table id="T_2f55e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f55e_level0_col0" class="col_heading level0 col0" >MAPE</th>
#       <th id="T_2f55e_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_2f55e_level0_col2" class="col_heading level0 col2" >sMAPE</th>
#       <th id="T_2f55e_level0_col3" class="col_heading level0 col3" >MAPE Ranking</th>
#       <th id="T_2f55e_level0_col4" class="col_heading level0 col4" >RMSE Ranking</th>
#       <th id="T_2f55e_level0_col5" class="col_heading level0 col5" >sMAPE Ranking</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f55e_level0_row0" class="row_heading level0 row0" >AutoSARIMA</th>
#       <td id="T_2f55e_row0_col0" class="data row0 col0" >0.022</td>
#       <td id="T_2f55e_row0_col1" class="data row0 col1" >1.990</td>
#       <td id="T_2f55e_row0_col2" class="data row0 col2" >1.491</td>
#       <td id="T_2f55e_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_2f55e_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_2f55e_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row1" class="row_heading level0 row1" >Exponential Smoothing</th>
#       <td id="T_2f55e_row1_col0" class="data row1 col0" >0.022</td>
#       <td id="T_2f55e_row1_col1" class="data row1 col1" >2.014</td>
#       <td id="T_2f55e_row1_col2" class="data row1 col2" >1.499</td>
#       <td id="T_2f55e_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_2f55e_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_2f55e_row1_col5" class="data row1 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row2" class="row_heading level0 row2" >Naive</th>
#       <td id="T_2f55e_row2_col0" class="data row2 col0" >0.023</td>
#       <td id="T_2f55e_row2_col1" class="data row2 col1" >2.015</td>
#       <td id="T_2f55e_row2_col2" class="data row2 col2" >1.522</td>
#       <td id="T_2f55e_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_2f55e_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_2f55e_row2_col5" class="data row2 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row3" class="row_heading level0 row3" >Naive (drift)</th>
#       <td id="T_2f55e_row3_col0" class="data row3 col0" >0.023</td>
#       <td id="T_2f55e_row3_col1" class="data row3 col1" >2.019</td>
#       <td id="T_2f55e_row3_col2" class="data row3 col2" >1.523</td>
#       <td id="T_2f55e_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_2f55e_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_2f55e_row3_col5" class="data row3 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row4" class="row_heading level0 row4" >Meta Ensemble: SVR</th>
#       <td id="T_2f55e_row4_col0" class="data row4 col0" >0.023</td>
#       <td id="T_2f55e_row4_col1" class="data row4 col1" >2.118</td>
#       <td id="T_2f55e_row4_col2" class="data row4 col2" >1.538</td>
#       <td id="T_2f55e_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_2f55e_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_2f55e_row4_col5" class="data row4 col5" >5</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row5" class="row_heading level0 row5" >Weighted Ensemble: Inverse Error Covariance</th>
#       <td id="T_2f55e_row5_col0" class="data row5 col0" >0.023</td>
#       <td id="T_2f55e_row5_col1" class="data row5 col1" >2.084</td>
#       <td id="T_2f55e_row5_col2" class="data row5 col2" >1.562</td>
#       <td id="T_2f55e_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_2f55e_row5_col4" class="data row5 col4" >5</td>
#       <td id="T_2f55e_row5_col5" class="data row5 col5" >6</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row6" class="row_heading level0 row6" >Weighted Ensemble: Inverse RMSE</th>
#       <td id="T_2f55e_row6_col0" class="data row6 col0" >0.024</td>
#       <td id="T_2f55e_row6_col1" class="data row6 col1" >2.122</td>
#       <td id="T_2f55e_row6_col2" class="data row6 col2" >1.568</td>
#       <td id="T_2f55e_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_2f55e_row6_col4" class="data row6 col4" >7</td>
#       <td id="T_2f55e_row6_col5" class="data row6 col5" >7</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row7" class="row_heading level0 row7" >Meta Ensemble: Random Forest</th>
#       <td id="T_2f55e_row7_col0" class="data row7 col0" >0.024</td>
#       <td id="T_2f55e_row7_col1" class="data row7 col1" >2.269</td>
#       <td id="T_2f55e_row7_col2" class="data row7 col2" >1.603</td>
#       <td id="T_2f55e_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_2f55e_row7_col4" class="data row7 col4" >8</td>
#       <td id="T_2f55e_row7_col5" class="data row7 col5" >8</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row8" class="row_heading level0 row8" >Weighted Ensemble: Inverse Variance</th>
#       <td id="T_2f55e_row8_col0" class="data row8 col0" >0.026</td>
#       <td id="T_2f55e_row8_col1" class="data row8 col1" >2.335</td>
#       <td id="T_2f55e_row8_col2" class="data row8 col2" >1.710</td>
#       <td id="T_2f55e_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_2f55e_row8_col4" class="data row8 col4" >9</td>
#       <td id="T_2f55e_row8_col5" class="data row8 col5" >9</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row9" class="row_heading level0 row9" >XGBoost</th>
#       <td id="T_2f55e_row9_col0" class="data row9 col0" >0.026</td>
#       <td id="T_2f55e_row9_col1" class="data row9 col1" >2.500</td>
#       <td id="T_2f55e_row9_col2" class="data row9 col2" >1.772</td>
#       <td id="T_2f55e_row9_col3" class="data row9 col3" >10</td>
#       <td id="T_2f55e_row9_col4" class="data row9 col4" >11</td>
#       <td id="T_2f55e_row9_col5" class="data row9 col5" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row10" class="row_heading level0 row10" >Weighted Ensemble: Simple</th>
#       <td id="T_2f55e_row10_col0" class="data row10 col0" >0.027</td>
#       <td id="T_2f55e_row10_col1" class="data row10 col1" >2.411</td>
#       <td id="T_2f55e_row10_col2" class="data row10 col2" >1.778</td>
#       <td id="T_2f55e_row10_col3" class="data row10 col3" >11</td>
#       <td id="T_2f55e_row10_col4" class="data row10 col4" >10</td>
#       <td id="T_2f55e_row10_col5" class="data row10 col5" >11</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row11" class="row_heading level0 row11" >STL</th>
#       <td id="T_2f55e_row11_col0" class="data row11 col0" >0.044</td>
#       <td id="T_2f55e_row11_col1" class="data row11 col1" >3.856</td>
#       <td id="T_2f55e_row11_col2" class="data row11 col2" >2.909</td>
#       <td id="T_2f55e_row11_col3" class="data row11 col3" >12</td>
#       <td id="T_2f55e_row11_col4" class="data row11 col4" >12</td>
#       <td id="T_2f55e_row11_col5" class="data row11 col5" >12</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row12" class="row_heading level0 row12" >skProphet</th>
#       <td id="T_2f55e_row12_col0" class="data row12 col0" >0.057</td>
#       <td id="T_2f55e_row12_col1" class="data row12 col1" >5.080</td>
#       <td id="T_2f55e_row12_col2" class="data row12 col2" >3.839</td>
#       <td id="T_2f55e_row12_col3" class="data row12 col3" >13</td>
#       <td id="T_2f55e_row12_col4" class="data row12 col4" >13</td>
#       <td id="T_2f55e_row12_col5" class="data row12 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_2f55e_level0_row13" class="row_heading level0 row13" >dartsProphet</th>
#       <td id="T_2f55e_row13_col0" class="data row13 col0" >0.058</td>
#       <td id="T_2f55e_row13_col1" class="data row13 col1" >5.114</td>
#       <td id="T_2f55e_row13_col2" class="data row13 col2" >3.898</td>
#       <td id="T_2f55e_row13_col3" class="data row13 col3" >14</td>
# Metrics ranking for TrendSeasRW:
# <style type="text/css">
# </style>
# <table id="T_684b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_684b7_level0_col0" class="col_heading level0 col0" >MAPE</th>
#       <th id="T_684b7_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_684b7_level0_col2" class="col_heading level0 col2" >sMAPE</th>
#       <th id="T_684b7_level0_col3" class="col_heading level0 col3" >MAPE Ranking</th>
#       <th id="T_684b7_level0_col4" class="col_heading level0 col4" >RMSE Ranking</th>
#       <th id="T_684b7_level0_col5" class="col_heading level0 col5" >sMAPE Ranking</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_684b7_level0_row0" class="row_heading level0 row0" >Weighted Ensemble: Inverse RMSE</th>
#       <td id="T_684b7_row0_col0" class="data row0 col0" >0.037</td>
#       <td id="T_684b7_row0_col1" class="data row0 col1" >3.268</td>
#       <td id="T_684b7_row0_col2" class="data row0 col2" >2.442</td>
#       <td id="T_684b7_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_684b7_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_684b7_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row1" class="row_heading level0 row1" >Weighted Ensemble: Inverse Variance</th>
#       <td id="T_684b7_row1_col0" class="data row1 col0" >0.037</td>
#       <td id="T_684b7_row1_col1" class="data row1 col1" >3.297</td>
#       <td id="T_684b7_row1_col2" class="data row1 col2" >2.460</td>
#       <td id="T_684b7_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_684b7_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_684b7_row1_col5" class="data row1 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row2" class="row_heading level0 row2" >Weighted Ensemble: Simple</th>
#       <td id="T_684b7_row2_col0" class="data row2 col0" >0.037</td>
#       <td id="T_684b7_row2_col1" class="data row2 col1" >3.331</td>
#       <td id="T_684b7_row2_col2" class="data row2 col2" >2.492</td>
#       <td id="T_684b7_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_684b7_row2_col4" class="data row2 col4" >5</td>
#       <td id="T_684b7_row2_col5" class="data row2 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row3" class="row_heading level0 row3" >Weighted Ensemble: Inverse Error Covariance</th>
#       <td id="T_684b7_row3_col0" class="data row3 col0" >0.037</td>
#       <td id="T_684b7_row3_col1" class="data row3 col1" >3.328</td>
#       <td id="T_684b7_row3_col2" class="data row3 col2" >2.492</td>
#       <td id="T_684b7_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_684b7_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_684b7_row3_col5" class="data row3 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row4" class="row_heading level0 row4" >Exponential Smoothing</th>
#       <td id="T_684b7_row4_col0" class="data row4 col0" >0.038</td>
#       <td id="T_684b7_row4_col1" class="data row4 col1" >3.341</td>
#       <td id="T_684b7_row4_col2" class="data row4 col2" >2.498</td>
#       <td id="T_684b7_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_684b7_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_684b7_row4_col5" class="data row4 col5" >5</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row5" class="row_heading level0 row5" >AutoSARIMA</th>
#       <td id="T_684b7_row5_col0" class="data row5 col0" >0.038</td>
#       <td id="T_684b7_row5_col1" class="data row5 col1" >3.294</td>
#       <td id="T_684b7_row5_col2" class="data row5 col2" >2.529</td>
#       <td id="T_684b7_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_684b7_row5_col4" class="data row5 col4" >2</td>
#       <td id="T_684b7_row5_col5" class="data row5 col5" >6</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row6" class="row_heading level0 row6" >Meta Ensemble: SVR</th>
#       <td id="T_684b7_row6_col0" class="data row6 col0" >0.039</td>
#       <td id="T_684b7_row6_col1" class="data row6 col1" >3.490</td>
#       <td id="T_684b7_row6_col2" class="data row6 col2" >2.635</td>
#       <td id="T_684b7_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_684b7_row6_col4" class="data row6 col4" >7</td>
#       <td id="T_684b7_row6_col5" class="data row6 col5" >7</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row7" class="row_heading level0 row7" >Naive</th>
#       <td id="T_684b7_row7_col0" class="data row7 col0" >0.041</td>
#       <td id="T_684b7_row7_col1" class="data row7 col1" >3.502</td>
#       <td id="T_684b7_row7_col2" class="data row7 col2" >2.725</td>
#       <td id="T_684b7_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_684b7_row7_col4" class="data row7 col4" >8</td>
#       <td id="T_684b7_row7_col5" class="data row7 col5" >8</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row8" class="row_heading level0 row8" >Naive (drift)</th>
#       <td id="T_684b7_row8_col0" class="data row8 col0" >0.041</td>
#       <td id="T_684b7_row8_col1" class="data row8 col1" >3.512</td>
#       <td id="T_684b7_row8_col2" class="data row8 col2" >2.734</td>
#       <td id="T_684b7_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_684b7_row8_col4" class="data row8 col4" >9</td>
#       <td id="T_684b7_row8_col5" class="data row8 col5" >9</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row9" class="row_heading level0 row9" >Meta Ensemble: Random Forest</th>
#       <td id="T_684b7_row9_col0" class="data row9 col0" >0.042</td>
#       <td id="T_684b7_row9_col1" class="data row9 col1" >3.673</td>
#       <td id="T_684b7_row9_col2" class="data row9 col2" >2.788</td>
#       <td id="T_684b7_row9_col3" class="data row9 col3" >10</td>
#       <td id="T_684b7_row9_col4" class="data row9 col4" >10</td>
#       <td id="T_684b7_row9_col5" class="data row9 col5" >10</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row10" class="row_heading level0 row10" >XGBoost</th>
#       <td id="T_684b7_row10_col0" class="data row10 col0" >0.044</td>
#       <td id="T_684b7_row10_col1" class="data row10 col1" >4.103</td>
#       <td id="T_684b7_row10_col2" class="data row10 col2" >2.976</td>
#       <td id="T_684b7_row10_col3" class="data row10 col3" >11</td>
#       <td id="T_684b7_row10_col4" class="data row10 col4" >11</td>
#       <td id="T_684b7_row10_col5" class="data row10 col5" >11</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row11" class="row_heading level0 row11" >STL</th>
#       <td id="T_684b7_row11_col0" class="data row11 col0" >0.049</td>
#       <td id="T_684b7_row11_col1" class="data row11 col1" >4.413</td>
#       <td id="T_684b7_row11_col2" class="data row11 col2" >3.274</td>
#       <td id="T_684b7_row11_col3" class="data row11 col3" >12</td>
#       <td id="T_684b7_row11_col4" class="data row11 col4" >12</td>
#       <td id="T_684b7_row11_col5" class="data row11 col5" >12</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row12" class="row_heading level0 row12" >skProphet</th>
#       <td id="T_684b7_row12_col0" class="data row12 col0" >0.062</td>
#       <td id="T_684b7_row12_col1" class="data row12 col1" >5.306</td>
#       <td id="T_684b7_row12_col2" class="data row12 col2" >4.099</td>
#       <td id="T_684b7_row12_col3" class="data row12 col3" >13</td>
#       <td id="T_684b7_row12_col4" class="data row12 col4" >13</td>
#       <td id="T_684b7_row12_col5" class="data row12 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_684b7_level0_row13" class="row_heading level0 row13" >dartsProphet</th>
#       <td id="T_684b7_row13_col0" class="data row13 col0" >0.062</td>
#       <td id="T_684b7_row13_col1" class="data row13 col1" >5.315</td>
#       <td id="T_684b7_row13_col2" class="data row13 col2" >4.110</td>
#       <td id="T_684b7_row13_col3" class="data row13 col3" >14</td>
# Metrics ranking for WeakSARIMA:
# <style type="text/css">
# </style>
# <table id="T_a5031">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5031_level0_col0" class="col_heading level0 col0" >MAPE</th>
#       <th id="T_a5031_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_a5031_level0_col2" class="col_heading level0 col2" >sMAPE</th>
#       <th id="T_a5031_level0_col3" class="col_heading level0 col3" >MAPE Ranking</th>
#       <th id="T_a5031_level0_col4" class="col_heading level0 col4" >RMSE Ranking</th>
#       <th id="T_a5031_level0_col5" class="col_heading level0 col5" >sMAPE Ranking</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5031_level0_row0" class="row_heading level0 row0" >Weighted Ensemble: Inverse Error Covariance</th>
#       <td id="T_a5031_row0_col0" class="data row0 col0" >0.030</td>
#       <td id="T_a5031_row0_col1" class="data row0 col1" >2.737</td>
#       <td id="T_a5031_row0_col2" class="data row0 col2" >2.004</td>
#       <td id="T_a5031_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_a5031_row0_col4" class="data row0 col4" >3</td>
#       <td id="T_a5031_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row1" class="row_heading level0 row1" >Weighted Ensemble: Inverse RMSE</th>
#       <td id="T_a5031_row1_col0" class="data row1 col0" >0.030</td>
#       <td id="T_a5031_row1_col1" class="data row1 col1" >2.711</td>
#       <td id="T_a5031_row1_col2" class="data row1 col2" >2.008</td>
#       <td id="T_a5031_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_a5031_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_a5031_row1_col5" class="data row1 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row2" class="row_heading level0 row2" >Weighted Ensemble: Inverse Variance</th>
#       <td id="T_a5031_row2_col0" class="data row2 col0" >0.031</td>
#       <td id="T_a5031_row2_col1" class="data row2 col1" >2.770</td>
#       <td id="T_a5031_row2_col2" class="data row2 col2" >2.050</td>
#       <td id="T_a5031_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_a5031_row2_col4" class="data row2 col4" >5</td>
#       <td id="T_a5031_row2_col5" class="data row2 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row3" class="row_heading level0 row3" >Exponential Smoothing</th>
#       <td id="T_a5031_row3_col0" class="data row3 col0" >0.031</td>
#       <td id="T_a5031_row3_col1" class="data row3 col1" >2.744</td>
#       <td id="T_a5031_row3_col2" class="data row3 col2" >2.056</td>
#       <td id="T_a5031_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_a5031_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_a5031_row3_col5" class="data row3 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row4" class="row_heading level0 row4" >AutoSARIMA</th>
#       <td id="T_a5031_row4_col0" class="data row4 col0" >0.031</td>
#       <td id="T_a5031_row4_col1" class="data row4 col1" >2.710</td>
#       <td id="T_a5031_row4_col2" class="data row4 col2" >2.073</td>
#       <td id="T_a5031_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_a5031_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_a5031_row4_col5" class="data row4 col5" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row5" class="row_heading level0 row5" >Weighted Ensemble: Simple</th>
#       <td id="T_a5031_row5_col0" class="data row5 col0" >0.031</td>
#       <td id="T_a5031_row5_col1" class="data row5 col1" >2.820</td>
#       <td id="T_a5031_row5_col2" class="data row5 col2" >2.096</td>
#       <td id="T_a5031_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_a5031_row5_col4" class="data row5 col4" >8</td>
#       <td id="T_a5031_row5_col5" class="data row5 col5" >6</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row6" class="row_heading level0 row6" >Meta Ensemble: SVR</th>
#       <td id="T_a5031_row6_col0" class="data row6 col0" >0.032</td>
#       <td id="T_a5031_row6_col1" class="data row6 col1" >2.911</td>
#       <td id="T_a5031_row6_col2" class="data row6 col2" >2.120</td>
#       <td id="T_a5031_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_a5031_row6_col4" class="data row6 col4" >9</td>
#       <td id="T_a5031_row6_col5" class="data row6 col5" >7</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row7" class="row_heading level0 row7" >Meta Ensemble: Random Forest</th>
#       <td id="T_a5031_row7_col0" class="data row7 col0" >0.032</td>
#       <td id="T_a5031_row7_col1" class="data row7 col1" >2.961</td>
#       <td id="T_a5031_row7_col2" class="data row7 col2" >2.166</td>
#       <td id="T_a5031_row7_col3" class="data row7 col3" >8</td>
#       <td id="T_a5031_row7_col4" class="data row7 col4" >10</td>
#       <td id="T_a5031_row7_col5" class="data row7 col5" >8</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row8" class="row_heading level0 row8" >Naive</th>
#       <td id="T_a5031_row8_col0" class="data row8 col0" >0.033</td>
#       <td id="T_a5031_row8_col1" class="data row8 col1" >2.791</td>
#       <td id="T_a5031_row8_col2" class="data row8 col2" >2.195</td>
#       <td id="T_a5031_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_a5031_row8_col4" class="data row8 col4" >6</td>
#       <td id="T_a5031_row8_col5" class="data row8 col5" >9</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row9" class="row_heading level0 row9" >Naive (drift)</th>
#       <td id="T_a5031_row9_col0" class="data row9 col0" >0.033</td>
#       <td id="T_a5031_row9_col1" class="data row9 col1" >2.799</td>
#       <td id="T_a5031_row9_col2" class="data row9 col2" >2.199</td>
#       <td id="T_a5031_row9_col3" class="data row9 col3" >10</td>
#       <td id="T_a5031_row9_col4" class="data row9 col4" >7</td>
#       <td id="T_a5031_row9_col5" class="data row9 col5" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row10" class="row_heading level0 row10" >XGBoost</th>
#       <td id="T_a5031_row10_col0" class="data row10 col0" >0.035</td>
#       <td id="T_a5031_row10_col1" class="data row10 col1" >3.181</td>
#       <td id="T_a5031_row10_col2" class="data row10 col2" >2.328</td>
#       <td id="T_a5031_row10_col3" class="data row10 col3" >11</td>
#       <td id="T_a5031_row10_col4" class="data row10 col4" >11</td>
#       <td id="T_a5031_row10_col5" class="data row10 col5" >11</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row11" class="row_heading level0 row11" >STL</th>
#       <td id="T_a5031_row11_col0" class="data row11 col0" >0.045</td>
#       <td id="T_a5031_row11_col1" class="data row11 col1" >4.000</td>
#       <td id="T_a5031_row11_col2" class="data row11 col2" >2.980</td>
#       <td id="T_a5031_row11_col3" class="data row11 col3" >12</td>
#       <td id="T_a5031_row11_col4" class="data row11 col4" >12</td>
#       <td id="T_a5031_row11_col5" class="data row11 col5" >12</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row12" class="row_heading level0 row12" >dartsProphet</th>
#       <td id="T_a5031_row12_col0" class="data row12 col0" >0.058</td>
#       <td id="T_a5031_row12_col1" class="data row12 col1" >4.982</td>
#       <td id="T_a5031_row12_col2" class="data row12 col2" >3.864</td>
#       <td id="T_a5031_row12_col3" class="data row12 col3" >13</td>
#       <td id="T_a5031_row12_col4" class="data row12 col4" >13</td>
#       <td id="T_a5031_row12_col5" class="data row12 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_a5031_level0_row13" class="row_heading level0 row13" >skProphet</th>
#       <td id="T_a5031_row13_col0" class="data row13 col0" >0.058</td>
#       <td id="T_a5031_row13_col1" class="data row13 col1" >5.017</td>
#       <td id="T_a5031_row13_col2" class="data row13 col2" >3.894</td>
#       <td id="T_a5031_row13_col3" class="data row13 col3" >14</td>

# %% [markdown]
# Note: For now you need to restart kernel and if you want to re-run pipeline with different settings.

# %%
display_ranking_table(output_dictionaries['metrics ranking'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 display_ranking_table(output_dictionaries['metrics ranking'])
#
# KeyError: 'metrics ranking'
