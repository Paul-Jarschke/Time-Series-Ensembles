# %% [markdown]
# ### Load Dependencies

# %%
import os.path

from src.utils.paths import *
from src.utils import pull_results, plot_metrics
# Out:
# Loading helper functions...
# Loading paths...

# %% [markdown]
# ### Update Currently Analyzed Data

# %%
timestamp = "20240712_2211"
pull_results(timestamp=timestamp, file_prefix="noisy_simdata_compl")  # Comment out this code if data did not change.
# Out:
# Finished pulling files!

# %% [markdown]
# #### Plot (and Export) Metrics Ranking

# %%
plot_metrics("MAPE", remove_models=["Meta Ensemble: MLP"], export=True)
# Out:
# Export successful!
