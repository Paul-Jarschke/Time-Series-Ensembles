# %% [markdown]
# ### Load Dependencies

# %%
# Out:
# Loading helper functions...
# Loading paths...

# %% [markdown]
# ### Update Currently Analyzed Data

# %%
# timestamp = "20240712_2211"
# pull_results(timestamp=timestamp, file_prefix="noisy_simdata_compl")  # Comment out this code if data did not change.

# %% [markdown]
# #### Plot (and Export) Metrics Ranking

# %%
plot_metrics(
    metric="MAPE", 
    data_labels=["RW", "TrendSeasRW", "WeakSARIMA", "StrongSARIMA", "SARIMAX"],
    remove_models=["Meta Ensemble: MLP", "Meta Ensemble: Linear Regression", "Weighted Ensemble: Inverse RMSE"], 
    export=True)
# Out:
# Dataset: RW_metrics_ranking.csv
# Best Model: AutoSARIMA
# MAPE Value: 0.0570566292476651
# Dataset: SARIMAX_metrics_ranking.csv
# Best Model: Exponential Smoothing
# MAPE Value: 0.0278102410313658
# Dataset: StrongSARIMA_metrics_ranking.csv
# Best Model: AutoSARIMA
# MAPE Value: 0.0223771464860858
# Dataset: TrendSeasRW_metrics_ranking.csv
# Best Model: AutoSARIMA
# MAPE Value: 0.0380231659495721
# Dataset: WeakSARIMA_metrics_ranking.csv
# Best Model: AutoSARIMA
# MAPE Value: 0.03114790244944
# ['Naive', 'Best Forecaster']
# Export successful!
